# %%
# %cd /home/brimmann/works/xRAG
# Out:
# /home/brimmann/works/xRAG
# /home/brimmann/works/xRAG/.venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import torch.nn as nn
import re
from types import SimpleNamespace
import torch
from src.distill.models.projector_xmistral_modeling import Xmistral7bProjector

# %%
teacher_projector_config = SimpleNamespace(
    projector_type='mlp2x_gelu',
    retriever_hidden_size=4096,
    hidden_size=4096
)

teacher_projector = Xmistral7bProjector(teacher_projector_config)

# %%
teacher_projector.load_state_dict(torch.load("teacher_projector_weights.pth"))
# Out:
# <All keys matched successfully>

# %%
teacher_projector
# Out:
# Xmistral7bProjector(
#   (projector): Sequential(
#     (0): Linear(in_features=4096, out_features=4096, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#   )
# )

# %%
from src.distill.models.proejector_xgemma_modeling import XGemma22bProjector

student_projector_config = SimpleNamespace(
    projector_type='mlp2x_gelu',
    retriever_hidden_size=4096,
    hidden_size=4096,
    adaptor_hidden_size=2304
)

student_projector = XGemma22bProjector(student_projector_config)

# %%
student_projector
# Out:
# XGemma22bProjector(
#   (projector): Sequential(
#     (0): Linear(in_features=4096, out_features=4096, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): Linear(in_features=4096, out_features=2304, bias=True)
#   )
# )
