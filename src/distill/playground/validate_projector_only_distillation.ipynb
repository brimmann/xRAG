# %%
from projector_model import ProjectorConfig, ProjectorModel

# %%
# Create a configuration
config = ProjectorConfig()

# Instantiate the model from the configuration
model = ProjectorModel(config)

print(model)
# Out:
# ProjectorModel(
#   (projector): Projector(
#     (projector): Sequential(
#       (0): Linear(in_features=128, out_features=4096, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=4096, out_features=4096, bias=True)
#     )
#   )
# )

# %%
import torch

# %%
# Dummy input tensor with batch size 1, 5 tokens
batch_size = 1
num_documents = 5
retriever_hidden_size = config.retriever_hidden_size

dummy_input = torch.randn(batch_size, num_documents, retriever_hidden_size)
print(f"Shape of dummy_input: {dummy_input.shape}")
# Out:
# Shape of dummy_input: torch.Size([1, 5, 128])
