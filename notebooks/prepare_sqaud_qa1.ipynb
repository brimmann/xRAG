# %%
from datasets import load_dataset

# %%
ds = load_dataset("brimmann2/squad-v2-sampled2")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['gem_id', 'id', 'title', 'context', 'question', 'target', 'references', 'answers'],
#         num_rows: 24000
#     })
#     validation: Dataset({
#         features: ['gem_id', 'id', 'title', 'context', 'question', 'target', 'references', 'answers'],
#         num_rows: 2400
#     })
# })

# %%
transformed_dataset = ds.map(
    lambda example: {'id': example['id'], 'text': example['context']},
    remove_columns=ds['train'].column_names,
    batched=True # Process data in batches for efficiency
)
# Out:
# ...
# Map: 100%|██████████| 2400/2400 [00:00<00:00, 210346.24 examples/s]

# %%
transformed_dataset["dev"] = transformed_dataset.pop("validation")

# %%
transformed_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'text'],
#         num_rows: 24000
#     })
#     dev: Dataset({
#         features: ['id', 'text'],
#         num_rows: 2400
#     })
# })

# %%
transformed_dataset.push_to_hub("brimmann2/squad_qa1")
# Out:
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 20.45ba/s]
# Processing Files (1 / 1): 100%|██████████| 11.4MB / 11.4MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# ...
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 154.66ba/s]
# Processing Files (1 / 1): 100%|██████████| 1.11MB / 1.11MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.41s/ shards]
# CommitInfo(commit_url='https://huggingface.co/datasets/brimmann2/squad_qa1/commit/5ff2fa0bb43e4fef8fe0dff2eda9f0c191a510ec', commit_message='Upload dataset', commit_description='', oid='5ff2fa0bb43e4fef8fe0dff2eda9f0c191a510ec', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/brimmann2/squad_qa1', endpoint='https://huggingface.co', repo_type='dataset', repo_id='brimmann2/squad_qa1'), pr_revision=None, pr_num=None)
